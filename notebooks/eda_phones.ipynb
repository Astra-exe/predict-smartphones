# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/refurbished_phones.csv', encoding='latin-1')
df.head()
# Out:
#   Company Name            Model Name  RAM   Processor  Battery Capacity  \
# 0        Apple       iPhone 16 128GB    6  A17 Bionic              3600
# 1        Apple       iPhone 16 256GB    6  A17 Bionic              3600
# 2        Apple       iPhone 16 512GB    6  A17 Bionic              3600
# 3        Apple  iPhone 16 Plus 128GB    6  A17 Bionic              4200
# 4        Apple  iPhone 16 Plus 256GB    6  A17 Bionic              4200
#
#    Screen Size  Launched Year  Condition  age_years  Launched Price (USA)  \
# 0          6.1           2024       Good          1                 799.0
# 1          6.1           2024    regular          1                 849.0
# 2          6.1           2024       Good          1                 899.0
# 3          6.7           2024       Good          1                 899.0
# 4          6.7           2024  Excellent          1                 949.0
#
#    price_drop  refurbished_price
# 0        0.35             501.06
# 1        0.50             422.87
# 2        0.35             577.08
# 3        0.35             573.97
# 4        0.20             748.02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company Name          928 non-null    object
#  1   Model Name            928 non-null    object
#  2   RAM                   928 non-null    int64
#  3   Processor             928 non-null    object
#  4   Battery Capacity      928 non-null    int64
#  5   Screen Size           928 non-null    float64
#  6   Launched Year         928 non-null    int64
#  7   Condition             928 non-null    object
#  8   age_years             928 non-null    int64
#  9   Launched Price (USA)  928 non-null    float64
#  10  price_drop            928 non-null    float64
#  11  refurbished_price     928 non-null    float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 87.1+ KB

# %%
df.describe()
# Out:
#               RAM  Battery Capacity  Screen Size  Launched Year   age_years  \
# count  928.000000        928.000000   928.000000     928.000000  928.000000
# mean     7.807112       5026.219828     7.079558    2022.206897    2.806034
# std      3.175634       1357.009227     1.531843       1.841707    1.825472
# min      1.000000       2000.000000     5.000000    2014.000000    1.000000
# 25%      6.000000       4400.000000     6.500000    2021.000000    1.000000
# 50%      8.000000       5000.000000     6.670000    2023.000000    2.000000
# 75%      8.000000       5100.000000     6.780000    2024.000000    4.000000
# max     16.000000      11200.000000    14.600000    2025.000000   11.000000
#
#        Launched Price (USA)  price_drop  refurbished_price
# count            928.000000  928.000000         928.000000
# mean             626.618168    0.434860         352.046778
# std             1348.804231    0.132927         734.824951
# min               79.000000    0.200000          31.710000
# 25%              256.750000    0.350000         139.835000
# 50%              449.000000    0.400000         248.380000
# 75%              849.000000    0.550000         447.237500
# max            39622.000000    0.700000       21217.840000

# %%
df['Company Name'].unique()
# Out:
# array(['Apple', 'Samsung', 'OnePlus', 'Vivo', 'iQOO', 'Oppo', 'Realme',
#        'Xiaomi', 'Lenovo', 'Motorola', 'Huawei', 'Nokia', 'Sony',
#        'Google', 'Tecno', 'Infinix', 'Honor', 'POCO', 'Poco'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# Company Name            0
# Model Name              0
# RAM                     0
# Processor               0
# Battery Capacity        0
# Screen Size             0
# Launched Year           0
# Condition               0
# age_years               0
# Launched Price (USA)    0
# price_drop              0
# refurbished_price       0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
corr_matrix = df.select_dtypes(include=np.number).corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlaciones entre Variables")
plt.show()
